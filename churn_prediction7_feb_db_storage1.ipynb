# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
column_names = df.columns.tolist()

# %%
column_names
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
import mysql.connector

# Connect to MySQL
conn = mysql.connector.connect(
    host="host_name",
    user="user_name", 
    password="your_password"  
)

cursor = conn.cursor()

# Create database
cursor.execute("CREATE DATABASE IF NOT EXISTS customer_churn")
cursor.execute("USE customer_churn")

# Create table
cursor.execute("""
    CREATE TABLE IF NOT EXISTS customers (
    customerID VARCHAR(20) PRIMARY KEY,
    gender VARCHAR(10),
    SeniorCitizen BOOLEAN,
    Partner VARCHAR(5),
    Dependents VARCHAR(5),
    tenure INT,
    PhoneService VARCHAR(5),
    MultipleLines VARCHAR(20),
    InternetService VARCHAR(20),
    OnlineSecurity VARCHAR(20),
    OnlineBackup VARCHAR(20),
    DeviceProtection VARCHAR(20),
    TechSupport VARCHAR(20),
    StreamingTV VARCHAR(20),
    StreamingMovies VARCHAR(20),
    Contract VARCHAR(20),
    PaperlessBilling VARCHAR(5),
    PaymentMethod VARCHAR(30),
    MonthlyCharges FLOAT,
    TotalCharges FLOAT,
    Churn VARCHAR(5)
);

""")

print("Database and Table created successfully.")
conn.close()
# Out:
# Database and Table created successfully.

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# Check for outliers using IQR (Interquartile Range)
Q1 = df['TotalCharges'].quantile(0.25)
Q3 = df['TotalCharges'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier range
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Count outliers
outliers = df[(df['TotalCharges'] < lower_bound) | (df['TotalCharges'] > upper_bound)]
print(f"Number of outliers: {len(outliers)}")

# Choose mean or median based on outliers
if len(outliers) > 0:
    print("Using Median for missing values (outliers detected).")
    df['TotalCharges'].fillna(df['TotalCharges'].median(), inplace=True)
else:
    print("Using Mean for missing values (no major outliers).")
    df['TotalCharges'].fillna(df['TotalCharges'].mean(), inplace=True)
# Out:
# Number of outliers: 0
# Using Mean for missing values (no major outliers).

# %%
import mysql.connector
import pandas as pd

# Connect to MySQL
conn = mysql.connector.connect(
    host="host",
    user="your_user", 
    password="your password",
    database="customer_churn"
)
cursor = conn.cursor()


# Convert DataFrame to list of tuples for MySQL insertion
columns = df.columns.tolist()
sql = f"""
    INSERT INTO customers ({', '.join(columns)}) 
    VALUES ({', '.join(['%s'] * len(columns))})
"""
values = [tuple(row) for _, row in df.iterrows()]

# ✅ Bulk insert for better performance
try:
    cursor.executemany(sql, values)  # Use executemany() instead of execute()
    conn.commit()
    print("Data inserted successfully.")
except mysql.connector.Error as err:
    print(f"Error: {err}")
finally:
    cursor.close()
    conn.close()  # Always close the connection
# Out:
# Data inserted successfully.
